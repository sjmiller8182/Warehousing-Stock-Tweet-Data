# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options  
import time

# %%
chrome_options = Options()  
chrome_options.add_argument("--headless")  
driver = webdriver.Chrome(options=chrome_options)

# %%
url = "https://stocktwits.com/symbol/AAPL"
driver.get(url) #navigate to the page

# %%
for i in range(1):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(4)
html_source = driver.page_source
data = html_source.encode('utf-8')

# %%
data
# Out:
# b'<html lang="en"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# profile: http://ogp.me/ns/profile#"><script src="https://cdn.ampproject.org/rtv/011909241711100/amp4ads-host-v0.js"></script><script type="text/javascript" async="" src="//static.criteo.net/js/ld/publishertag.prebid.js"></script><script src="https://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101"></script><script src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_rendering_2019092602.js"></script><script src="https://rules.quantcount.com/rules-p-UeXruRVtZz7w6.js" async=""></script><script async="" src="//confiant-integrations.global.ssl.fastly.net/prebid/201909301246/wrap.js"></script><script src="https://connect.facebook.net/signals/plugins/inferredEvents.js?v=2.9.4" async=""></script><script src="https://connect.facebook.net/signals/config/134240187179576?v=2.9.4&amp;r=stable" async=""></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script async="" type="text/javascript" src="https://sb.scorecardresearch.com/beacon.js"></script><script async="" type="text/javascript" src="https://hbx.media.net/bxl.js?cid=8CUFH1GPH&amp;dn=stocktwits.com&amp;version=&amp;https=1"></script><script async="" type="text/javascript" src="https://secure.quantserve.com/quant.js"></script><script async="" type="text/javascript" src="https://confiant-integrations.global.ssl.fastly.net/dvS98IKwDukcG6gPDYBBcCk9sKY/gpt_and_prebid/config.js"></script><script async="" src="//c.amazon-adsystem.com/aax2/apstag.js"></script><script src="https://connect.facebook.net/en_US/sdk.js?hash=a2813849c8260ad3069e521158084c1c&amp;ua=modern_es6" async="" crossorigin="anonymous"></script><meta charset="utf-8"><meta name="viewport" content="width=device-width, initial-scale=1.0"><meta name="apple-mobile-web-app-capable" content="yes"><title>AAPL Apple Inc. \xe2\x80\x94 Stock Price and Discussion | Stocktwits</title><meta data-react-helmet="true" property="og:url" content="https://stocktwits.com/symbol/AAPL"><meta data-react-helmet="true" property="og:image" content="https://stocktwits.com/assets/img/stocktwits-logomark-black.png"><meta data-react-helmet="true" property="og:image:width" content="200"><meta data-react-helmet="true" property="og:image:height" content="200"><meta data-react-helmet="true" name="twitter:card" content="summary"><meta data-react-helmet="true" name="twitter:image" content="https://stocktwits.com/assets/img/stocktwits-logomark-black.png"><meta data-react-helmet="true" property="og:description" content="Real-time trade and investing ideas on Apple Inc. AAPL from the largest community of traders and investors."><meta data-react-helmet="true" name="description" content="Real-time trade and investing ideas on Apple Inc. AAPL from the largest community of traders and investors."><meta data-react-helmet="true" name="twitter:description" content="Real-time trade and investing ideas on Apple Inc. AAPL from the largest community of traders and investors."><meta data-react-helmet="true" property="og:title" content="AAPL Apple Inc. \xe2\x80\x94 Stock Price and Discussion | Stocktwits"><meta data-react-helmet="true" name="twitter:title" content="AAPL Apple Inc. \xe2\x80\x94 Stock Price and Discussion | Stocktwits"><link data-react-helmet="true" href="https://stocktwits.com/symbol/AAPL" rel="canonical"><link rel="icon" href="/favicon.png"><link rel="icon" href="/favicon-16x16.png" sizes="16x16"><link rel="icon" href="/favicon-32x32.png" sizes="32x32"><meta name="keywords" content="stock, twitter, stocktwits, stock conversations, stock trends, financial trends, twitter stock, stocks on twitter, stock twitter,financial twitter, financial forum, financial advice, financial conversation, u_true"><meta property="og:site_name" content="Stocktwits"><meta property="og:type" content="article"><meta name="Author" content="StockTwits Inc (stocktwits.com)"><meta name="Copyright" content="Stocktwits"><meta name="application-n ...
