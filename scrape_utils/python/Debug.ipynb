# %%
from twitter import TwitterScraper
ts = TwitterScraper(path='~/Dropbox/twitterAcess.csv')

# %%
ts.connect()

# %%
status = ts.search('AAPL')

# %%
status['statuses']
# Out:
# [{'created_at': 'Sun Oct 06 22:38:18 +0000 2019',
#   'id': 1180975595930423297,
#   'id_str': '1180975595930423297',
#   'text': "RT @rachels_44: $AAPL 's weekly chart is looking strong...watching it to lead again. Resistances at 228, 230, 233. *Support at 223 https://…",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [{'text': 'AAPL', 'indices': [16, 21]}],
#    'user_mentions': [{'screen_name': 'rachels_44',
#      'name': 'Rachel',
#      'id': 936301908171612160,
#      'id_str': '936301908171612160',
#      'indices': [3, 14]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://play.google.com/store/apps/details?id=com.arthurivanets.owly" rel="nofollow">Оwly</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 3054340186,
# ...

# %%
status.keys()
# Out:
# dict_keys(['statuses', 'search_metadata'])
